# %%
import numpy as np
from glob import glob
import pandas as pd
from matplotlib import pyplot as plt
# %matplotlib inline
from PIL import Image, ImageFile
ImageFile.LOAD_TRUNCATED_IMAGES = True


# load filenames for human and dog images
dog_files = np.array(glob("/data/dog_images/*/*/*"))

# print number of images in each dataset

print('There are %d total dog images.' % len(dog_files))
# Out:
# There are 8351 total dog images.

# %%
classes = []
for i in range(0,len(dog_files)):
    clss = dog_files[i].split('/')[4][4:]
    classes.append(clss)

# %%
dog_cat, dog_count = np.unique(classes, return_counts=True)

# %%
dog_cat_df = pd.DataFrame(dog_cat)

# %%
dog_count_df = pd.DataFrame(dog_count)

# %%
dog_classes_df = pd.concat([dog_cat_df, dog_count_df], axis=1)

# %%
dog_classes_df.columns = ['dog_breed','Count']

# %%
dog_classes_df.sort_values('Count', ascending=False, inplace=True)

# %%
dog_classes_df.set_index('dog_breed', inplace=True)

# %%
dog_classes_df[:30].plot(kind='bar', legend=None);

# %%
dog_classes_df[100:].plot(kind='bar', legend=None);

# %%
# plot sample images

fig = plt.figure(figsize=(25, 4))
# display 20 images
for idx in np.arange(20):
    ax = fig.add_subplot(2, 20/2, idx+1, xticks=[], yticks=[])
    img=Image.open(dog_files[idx])
    plt.imshow(img)
    ax.set_title(dog_files[idx].split('/')[4][4:])

# %% [markdown]
# From above we see data has some order to it so we randomize in order for the model not fit according to the order
